# %%
###31/08/2019
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()   #learn working
# Out:
# 'C:\\Users\\asus1'

# %%
os.chdir('C:/Users/asus1/Desktop/bootcamp')

# %%
import seaborn.apionly as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
# C:\Users\asus1\Anaconda3\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   self[key] = other[key]
# C:\Users\asus1\Anaconda3\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# C:\Users\asus1\Anaconda3\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# C:\Users\asus1\Anaconda3\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# C:\Users\asus1\Anaconda3\lib\_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# C:\Users\asus1\Anaconda3\lib\site-packages\seaborn\apionly.py:9: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig,ax=plt.subplots()
ax.scatter(iris['sepal_length'],iris['sepal_width'])
ax.set(xlabel='sepal_length',ylabel ='sepal_width')
ax.set(title='Iris Dataset')
colors= {'setosa':'r', 'versicolor':'g','virginica':'b'}
fig,ax=plt.subplots()
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i],iris['sepal_width'][i],color=colors[iris['species'][i]])
    ax.set(xlabel='sepal_length',ylabel ='sepal_width')
    ax.set(title='Iris Dataset')

# %%
columns = iris.columns.drop(['species'])
x_data=range(0,iris.shape[0])
fig,ax=plt.subplots()
#for dongum columnsda geziyor
for column in columns :
    ax.plot(x_data,iris[column])
ax.legend(iris)
plt.show()

# %%
columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
plt.figure(figsize=(7,7))
x=iris["sepal_length"]
#bin hist genişliği
plt.hist(x,bins=100,color="orange")
plt.title("Sepal length in cm")
plt.xlabel("Sepal_length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(7,7))
iris.boxplot()
plt.figure()
plt.hist(iris["petal_length"],bins=100,color="orange")
plt.title("Histogram of Petal length ")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal length ')

# %%
##aralarındaki ilişkiyi gösteriyo
corr=iris.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
#korelasyonlara renk ataması
#korelasyon 0-1 arasındadır,0 çıkıınca lineer ilişki yok demektir,belki üstel bir etkileşim vardır
plt.matshow(iris.corr())
plt.show()

# %%
import numpy as np
import pandas as pd
rs=np.random.RandomState(0)
df=pd.DataFrame(rs.rand(10,10))
corr=df.corr()
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col1 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col2 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col7 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row0_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col0 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col3 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col5 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col7 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col8 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row1_col9 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row2_col0 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row2_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T
{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row4_col9 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col1 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col2 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col4 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col6 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col7 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col8 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_9dfae97e_ccca_11e9_9118_382c4a2ec379row5_col9 {
#             background-color:  #aec9fc;
#             color:  #000000;

# %%
df
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.548814  0.715189  0.602763  0.544883  0.423655  0.645894  0.437587
# 1  0.791725  0.528895  0.568045  0.925597  0.071036  0.087129  0.020218
# 2  0.978618  0.799159  0.461479  0.780529  0.118274  0.639921  0.143353
# 3  0.264556  0.774234  0.456150  0.568434  0.018790  0.617635  0.612096
# 4  0.359508  0.437032  0.697631  0.060225  0.666767  0.670638  0.210383
# 5  0.570197  0.438602  0.988374  0.102045  0.208877  0.161310  0.653108
# 6  0.158970  0.110375  0.656330  0.138183  0.196582  0.368725  0.820993
# 7  0.976459  0.468651  0.976761  0.604846  0.739264  0.039188  0.282807
# 8  0.317983  0.414263  0.064147  0.692472  0.566601  0.265389  0.523248
# 9  0.318569  0.667410  0.131798  0.716327  0.289406  0.183191  0.586513
#
#           7         8         9
# 0  0.891773  0.963663  0.383442
# 1  0.832620  0.778157  0.870012
# 2  0.944669  0.521848  0.414662
# 3  0.616934  0.943748  0.681820
# 4  0.128926  0.315428  0.363711
# 5  0.253292  0.466311  0.244426
# 6  0.097101  0.837945  0.096098
# 7  0.120197  0.296140  0.118728
# 8  0.093941  0.575946  0.929296
# 9  0.020108  0.828940  0.004695

# %%
import pandas as pd
titanic = pandas.read_csv("titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
#cross table to survived from sex
survived_sex=pd.crosstab(index=titanic["Survived"],columns=titanic["Sex"])
survived_sex
survived_sex.index=["died","survived"]
survived_sex
# Out:
# Sex       female  male
# died          81   468
# survived     233   109

# %%
survived_class=pd.crosstab(index=titanic["Survived"],columns=titanic["Pclass"])
#columnsları kendimiz isimlendirdik,isimlendirmeyedebiliriz
survived_class.columns=["class1","class2","class3"]
survived_class.index=["died","survived"]
survived_class
# Out:
#           class1  class2  class3
# died          80      97     372
# survived     136      87     119

# %%
print(type(titanic["Cabin"]))
char_cabin=titanic["Cabin"].astype(str)
#kabinlerin sadece baş harfini alıp yeni kabin oluşturduk
new_cabin=np.array([cabin[0] for cabin in char_cabin])
titanic["Cabin"]=pd.Categorical(new_cabin)
# Out:
# <class 'pandas.core.series.Series'>

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     n        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     n        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     n        S

# %%
#şimdi de kaç kişi A kabininden gelmiş kaç kişi B den gelmiş diye crosstab yapıyoruz
my_tab=pd.crosstab(index=titanic["Survived"],columns="count")
my_tab
pd.crosstab(index=titanic["Cabin"],columns="count")
# Out:
# col_0  count
# Cabin
# A         15
# B         47
# C         59
# D         33
# E         32
# F         13
# G          4
# T          1
# n        687

# %%
##Cabinle ölen yaşayan arasındaki ilişki
my_tab=pd.crosstab(index=titanic["Survived"],columns="count")
my_tab
pd.crosstab(index=titanic["Cabin"],columns=titanic["Survived"])
# Out:
# Survived    0    1
# Cabin
# A           8    7
# B          12   35
# C          24   35
# D           8   25
# E           8   24
# F           5    8
# G           2    2
# T           1    0
# n         481  206

# %%
#row ve column toplamlarını da yazalım
survived_class=pd.crosstab(index=titanic["Survived"],
                           columns=titanic["Pclass"],
                          margins=True)  #row ve column toplamlarını ifade eder
survived_class
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %%
#yüzde olarak dağılımlarını da göstermek için hücreleri toplama böldürürüm
survived_class.columns = ["class1","class2","class3","rowtotal"]
survived_class.index = ["died","survived","coltotal"]
survived_class
survived_class/survived_class.loc["coltotal","rowtotal"]
#survived_class/survived_class.ix["coltotal","rowtotal"]
# Out:
#             class1    class2    class3  rowtotal
# died      0.089787  0.108866  0.417508  0.616162
# survived  0.152637  0.097643  0.133558  0.383838
# coltotal  0.242424  0.206510  0.551066  1.000000

# %%
import pandas as pd
import numpy as np

d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

df=pd.DataFrame(d)
df
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65

# %%
print(df.sum())
# Out:
# Name      TomJamesRickyVinSteveSmithJackLeeDavidGasperBe...
# Age                                                     382
# Rating                                                44.92
# dtype: object

# %%
print(df.mean())
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %%
print(df.std())
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %%
#sadece nümerik değişknelerin değerini getirir
print(df.describe())
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %%
#tüm değişkenlerin değerini getirir
print(df.describe(include='all'))
# Out:
#        Name        Age     Rating
# count    12  12.000000  12.000000
# unique   12        NaN        NaN
# top     Lee        NaN        NaN
# freq      1        NaN        NaN
# mean    NaN  31.833333   3.743333
# std     NaN   9.232682   0.661628
# min     NaN  23.000000   2.560000
# 25%     NaN  25.000000   3.230000
# 50%     NaN  29.500000   3.790000
# 75%     NaN  35.500000   4.132500
# max     NaN  51.000000   4.800000

# %%
print(df.median())
# Out:
# Age       29.50
# Rating     3.79
# dtype: float64

# %%
from scipy.stats import norm
import seaborn as sns

#veri yarattık
veri_normal=norm.rvs(size=100000,loc=0,scale=1)

ax=sns.distplot(veri_normal)
ax=sns.distplot(veri_normal,bins=100,kde=True,color="red",hist_kws={"linewidth":15,"alpha":1})
ax.set(xlabel='Normal',ylabel ='Frekans')
# Out:
# [Text(0, 0.5, 'Frekans'), Text(0.5, 0, 'Normal')]

# %%
olcumler = np.array([17, 160, 234, 149, 145, 107, 197, 75, 201, 225, 211, 119, 
               157, 145, 127, 244, 163, 114, 145,  65, 112, 185, 202, 146,
               203, 224, 203, 114, 188, 156, 187, 154, 177, 95, 165, 50, 110, 
       216, 138, 151, 166, 135, 155, 84, 251, 173, 131, 207, 121, 120])

# %%
sns.distplot(olcumler)

# %%
from scipy import stats
#verinin describine bakalım
stats.describe(olcumler)
# Out:
# DescribeResult(nobs=50, minmax=(17, 251), mean=154.38, variance=2578.0363265306123, skewness=-0.32398897278694483, kurtosis=-0.05849823498415985)

# %%
##panda yalnızca dataframe ile çalıştığından dataframe atıp ordan hist çizdiririz,böylece dağılımın nasıl olduğuna karar veririz
pd.DataFrame(olcumler).plot.hist()

# %%
import pylab
#mavi olan bizim verilerimizin dağılımı, kırmızı ise olması gereken normal dağılım için
stats.probplot(olcumler,dist="norm",plot=pylab)
pylab.show()

# %%
import statsmodels.api as sm
sm.qqplot(olcumler,line="s")
pylab.show()

# %%
###shapiro testi
###normal dağılım mı değil mi test ediyorum
##statistic değerine bakıp tvalue bulduğun değer, pvalue kapsadığın alan yani pvalue alfadan büyükse normal dağılım diyosun 
###artık t test yapabilirim demek oluyor bu

from scipy.stats import shapiro
olcumler = np.array([17, 160, 234, 149, 145, 107, 197, 75, 201, 225, 211, 119, 
               157, 145, 127, 244, 163, 114, 145,  65, 112, 185, 202, 146,
               203, 224, 203, 114, 188, 156, 187, 154, 177, 95, 165, 50, 110, 
       216, 138, 151, 166, 135, 155, 84, 251, 173, 131, 207, 121, 120])
stat,p=shapiro(olcumler)
print('Statictics=%.3f, p=%.3f' %(stat,p))

alpha=0.5
if p >alpha:
    print('Orneklem Normal (Gaussian) dağılımdan gelmektedir, (Fail to reject)')  
else:
    print('Orneklem Normal (Gaussian) dağılım gostermemektedir, (Reject)')
# Out:
# Statictics=0.985, p=0.785
# Orneklem Normal (Gaussian) dağılımdan gelmektedir, (Fail to reject)
